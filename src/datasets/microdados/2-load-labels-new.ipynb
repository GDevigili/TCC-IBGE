# %%
# Imports
import sys
import os
sys.path.append('../..')

# Data Manipulation
import pandas as pd
import openpyxl

# %%
# Global Variables
DATA_PATH = "../../data/"

# %% [markdown]
# ## 1. Arquivos de Layout

# %%
# Carrega o arquivo de labels como um arquivo Excel
layout_2010 = pd.ExcelFile('2010_Layout_microdados_Amostra.xlsx')

# %%
# Funções Auxiliares

def remove_unnamed_columns(df) -> pd.DataFrame:
    """
    Remove colunas com nome Unnamed. Estas colunas vem de colunas que foram mescladas no .xlsx original.

    Args:
        df (pd.DataFrame): DataFrame com colunas Unnamed

    Returns:
        pd.DataFrame: DataFrame sem colunas Unnamed
    
    """
    return df.loc[:, ~df.columns.str.contains('^Unnamed')]


def get_values(split: list):
    values = {}
    for val in range(1, len(split)):
        aux = split[val].split('-')
        if len(aux) == 1:
            aux.append(aux[0])
            aux[0] = ' '    
        # aux[1] = aux[1].replace(' ', '')
        values[aux[0]] = aux[1]
    # print(values)
    return values


def split_col_names_values(col: pd.Series): 
    df = pd.DataFrame(columns = ['VAR', 'NOME', 'CHAVE', 'VALOR'])
    for index, value in col.items():
        df_aux = pd.DataFrame(columns = df.columns)
        split = value.split('\n')
        # df_aux['NOME'] = pd.concat([df_aux['NOME'], pd.Series(split[0])])
        if len(split) > 1:
            # series_values = pd.concat([series_values, pd.Series(get_values(split))])
            # df_line = pd.DataFrame(columns = ['NOME', 'CHAVES', 'VALORES'])
            # # df_line['NOME'] = pd.Series(split[0])
            # df_line = pd.Series(get_values)
            # dct = pd.Series(get_values)
            lst = [{'CHAVE': d_key, 'VALOR': d_value, 'VAR': index} for d_key, d_value in get_values(split).items()]
            df_aux = pd.DataFrame(lst)
            df_aux['NOME'] = split[0]
            
        else:
            df_aux['NOME'] = pd.Series(split[0])
            
        df = pd.concat([df, df_aux])
    return df


# def prepare_df(df: pd.DataFrame):
#     df_main = pd.DataFrame(columns = df.columns)
#     df = remove_unnamed_columns(df) 
#     for index, row in df.iterrows():
#         df_row = pd.DataFrame(columns = df.columns)
#         # for col in df.columns.drop('NOME'):
#         #     # print(entry)
#         #     df_row[col] = df[col]
#         df_row = pd.concat([df_row, split_col_names_values(row['NOME'])])
#         # print(df_entry)
#         df_aux = pd.concat([df_aux, df_row])
#     return df, df_aux

def prepare_df(df: pd.DataFrame)-> tuple:
    df = remove_unnamed_columns(df)
    df_vars = split_col_names_values(df.set_index('VAR')['NOME'])
    return df, df_vars

# %%
# Carrega as labels referentes aos microdados de domicílios
df_domi = pd.read_excel(layout_2010, sheet_name='DOMI')
df_domi.head()
# Out:
#      VAR                                               NOME  Unnamed: 2  \
# 0  V0001  UNIDADE DA FEDERAÇÃO:\n11- Rondônia\n12- Acre\...         NaN
# 1  V0002                                CÓDIGO DO MUNICÍPIO         NaN
# 2  V0011                                 ÁREA DE PONDERAÇÃO         NaN
# 3  V0300                                           CONTROLE         NaN
# 4  V0010                                      PESO AMOSTRAL         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  POSIÇÃO INICIAL  \
# 0         NaN         NaN         NaN         NaN                1
# 1         NaN         NaN         NaN         NaN                3
# 2         NaN         NaN         NaN         NaN                8
# 3         NaN         NaN         NaN         NaN               21
# 4         NaN         NaN         NaN         NaN               29
#
#    POSIÇÃO FINAL  INT   DEC TIPO
# 0              2    2   NaN    A
# 1              7    5   NaN    A
# 2             20   13   NaN    A
# 3             28    8   NaN    N
# 4             44    3  13.0    N

# %%
df_domi, df_domi_vars = prepare_df(df_domi)
df_domi.head()
# Out:
#      VAR                                               NOME  POSIÇÃO INICIAL  \
# 0  V0001  UNIDADE DA FEDERAÇÃO:\n11- Rondônia\n12- Acre\...                1
# 1  V0002                                CÓDIGO DO MUNICÍPIO                3
# 2  V0011                                 ÁREA DE PONDERAÇÃO                8
# 3  V0300                                           CONTROLE               21
# 4  V0010                                      PESO AMOSTRAL               29
#
#    POSIÇÃO FINAL  INT   DEC TIPO
# 0              2    2   NaN    A
# 1              7    5   NaN    A
# 2             20   13   NaN    A
# 3             28    8   NaN    N
# 4             44    3  13.0    N

# %%
# # Dataframe de pessoas
# df_pess = pd.read_excel(layout_2010, sheet_name='PESS')
# # Dataframe de emigração  
# df_emig = pd.read_excel(layout_2010, sheet_name='EMIG')
# # Dataframe de mortalidade
# df_mort = pd.read_excel(layout_2010, sheet_name='MORT')

# %%
MICRODATA_PATH = DATA_PATH + "microdados/"

dfs = {
    'amostra_domicilios_2010': df_domi,
    # 'amostra_pessoas_2010': df_pess,
    # 'amostra_emigracao_2010': df_emig,
    # 'amostra_mortalidade_2010': df_mort
}

dfs_vars = {
    'amostra_domicilios_2010': df_domi_vars,
    # 'amostra_pessoas_2010': df_pess_vars,
    # 'amostra_emigracao_2010': df_emig_vars,
    # 'amostra_mortalidade_2010': df_mort_vars
}

# %%
# Funções auxiliares

def split_by_index(input_string: str, indexes: list[int]) -> list[str]:
    """
    Splits a string into a list of strings using the indexes provided.
    
    Args:
        input_string (str): String to be split
        indexes (list[int]): List of indexes indicating where to split the string
        
    Returns:
        list[str]: List of splitted strings
    """
    return [input_string[i:j] for i, j in zip(indexes, indexes[1:] + [None])]


def extract_line_values(file: str, df: pd.DataFrame) -> dict[int, list[str]]:
    # open file
    with open(MICRODATA_PATH + file, 'r') as f:
        # create a counter for indexing the lines
        count = 0
        # create a dictionary to store the values
        values = {}
        # read all lines
        lines = f.readlines()
        # iterate over the lines
        for line in lines:
            # split the lines using the indexes from the dataframe
            line_values = split_by_index(line, df['POSIÇÃO INICIAL'].apply(lambda x: int(x) - 1).tolist())
            # save the values in the dictionary
            line_values[-1] = line_values[-1].replace('\n', '')
            values[count] = line_values
            count += 1
    # close the file
        f.close()
    return values


def process_microdata_files(file_list: list[str], df: dict[str, pd.DataFrame], df_vars: dict[str, pd.DataFrame]):
    """
    WORK IN PROGRESS
    """
    for file in file_list:
        print(f"Iniciando a extração do arquivo [{file}]")
        values = extract_line_values(file, df)
        print(values)

    # for file in os.listdir(dir_path):
    #     if "amostra" not in file:
    #         continue
    #     # get the name and year of the research from the file name
    #     # the format is amostra_domicilios_YYYY_UF.txt
    #     research = '_'.join(file.split('_')[:3])
    #     try:
    #         # extract the lines from the file
    #         values = extract_line_values(file, dfs[research])
    #         # translate the values
    #         translate_microdata(values, dfs[research])
    #     except KeyError:
    #         # print(f"O arquivo {file} não foi processado.");
    #         continue



def translate_microdata(line_values: str, df: pd.DataFrame, df_vars: pd.DataFrame):
    df_translated = pd.DataFrame(columns = df_vars['NOME'].unique().tolist())
    line_dict = {}
    # for each line, translate the int values to they true values
    for i in range(len(line_values)):
        
        # get the value that will be translaed
        value = line_values[i]
        # get the line from the dataframe    
        df_line = df.iloc[i]
        # get the name of the column (the ith unique column name)
        df_line_col_name = df_vars['NOME'].unique().tolist()[i]

        line_dict['VAR'] = df_line['VAR']
        # verify if the value is "translatable"
        if df_line['TIPO'] == 'C' or df_line['VAR'] == 'V0001':
            # if it is, get the possible values
            possible_values = df_vars[df_vars['VAR'] == df_line['VAR']]
            # get the value from the possible values
            translated_value = possible_values[possible_values['CHAVE'] == value]
            try:
                line_dict[df_line_col_name] = str(translated_value['VALOR'][0])
            except KeyError:
                line_dict[df_line_col_name] = str(value)
        else:
            line_dict[df_line_col_name] = value
    
    return line_dict

# %%
translate_microdata(sc_line_dict[0], dfs['amostra_domicilios_2010'], dfs_vars['amostra_domicilios_2010'])
# Out:
# {'VAR': 'V1005',
#  'UNIDADE DA FEDERAÇÃO:': '42',
#  'CÓDIGO DO MUNICÍPIO': '00051',
#  'ÁREA DE PONDERAÇÃO': '4200051001001',
#  'CONTROLE': '00000745',
#  'PESO AMOSTRAL': '0034868694751419',
#  'REGIÃO GEOGRÁFICA:': '4',
#  'CÓDIGO DA MESORREGIÃO:': '03',
#  'CÓDIGO DA MICRORREGIÃO:': '009',
#  'CÓDIGO DA REGIÃO METROPOLITANA:': '00',
#  'SITUAÇÃO DO DOMICÍLIO:': '2',
#  'ESPÉCIE DE UNIDADE VISITADA:': '01',
#  'TIPO DE ESPÉCIE:': '11',
#  'DOMICÍLIO, CONDIÇÃO DE OCUPAÇÃO:': '5',
#  'VALOR DO ALUGUEL (EM REAIS)             ': '      ',
#  'ALUGUEL EM Nº DE SALÁRIOS MÍNIMOS ': '         ',
#  'MATERIAL PREDOMINANTE, PAREDES EXTERNAS:': '3',
#  'CÔMODOS, NÚMERO:': '06',
#  'DENSIDADE DE MORADOR/CÔMODO ': '003',
#  'CÔMODOS COMO DORMITÓRIO, NÚMERO:': '01',
#  'DENSIDADE DE MORADOR / DORMITÓRIO  ': '020',
#  'BANHEIROS DE USO EXCLUSIVO, NÚMERO: ': '1',
#  'SANITÁRIO OU BURACO PARA DEJEÇÕES, EXISTÊNCIA:': ' ',
#  'ESGOTAMENTO SANITÁRIO, TIPO:': '3',
#  'ABASTECIMENTO DE ÁGUA, FORMA:': ' Rede geral de distribuição',
#  'ABASTECIMENTO DE ÁGUA, CANALIZAÇÃO:': ' Sim, em pelo menos um cômodo',
#  'LIXO, DESTINO:': '1',
#  'ENERGIA ELÉTRICA, EXISTÊNCIA:': ' Sim, de companhia distribuidora',
#  'EXISTÊNCIA DE MEDIDOR OU RELÓGIO, ENERGIA ELÉTRICA, COMPANHIA DISTRIBUIDORA:': '1',
#  'RÁDIO, EXISTÊNCIA:': '1',
#  'TELEVISÃO, EXISTÊNCIA:': ' Sim',
#  'MÁQUINA DE LAVAR ROUPA, EXISTÊNCIA:': ' Sim',
#  'GELADEIRA, EXISTÊNCIA:': ' Sim',
#  'TELEFONE CELULAR, EXISTÊNCIA:': ' Sim',
#  'TELEFONE FIXO, EXISTÊNCIA:': ' Sim',
#  'MICROCOMPUTADOR, EXISTÊNCIA:': ' Sim',
#  'MICROCOMPUTADOR COM ACESSO À INTERNET, EXISTÊNCIA:': '2',
#  'MOTOCICLETA PARA USO PARTICULAR, EXISTÊNCIA:': '2',
#  'AUTOMÓVEL PARA USO PARTICULAR, EXISTÊNCIA:': ' Sim',
#  'ALGUMA PESSOA QUE MORAVA COM VOCÊ(S) ESTAVA MORANDO EM OUTRO PAÍS EM 31 DE JULHO DE 2010:': '2',
#  'QUANTAS PESSOAS MORAVAM NESTE DOMICÍLIO EM 31 DE JULHO DE 2010': '02',
#  'A RESPONSABILIDADE PELO DOMICÍLIO É DE:': ' Apenas um morador',
#  'DE AGOSTO DE 2009 A JULHO DE 2010, FALECEU ALGUMA PESSOA QUE MORAVA COM VOCÊ(S) (INCLUSIVE CRIANÇAS RECÉM-NASCIDAS E IDOSOS):': '2',
#  'RENDIMENTO MENSAL DOMICILIAR EM JULHO DE 2010 ': '0003710',
#  'RENDIMENTO DOMICILIAR, SALÁRIOS MÍNIMOS, EM JULHO DE 2010 ': '0000727451',
#  'RENDIMENTO DOMICILIAR PER CAPITA EM JULHO DE 2010 ': '00185500',
#  'RENDIMENTO DOMICILIAR PER CAPITA, EM Nº DE SALÁRIOS MÍNIMOS, EM JULHO DE 2010 ': '000363725',
#  'Espécie da Unidade Doméstica': '2',
#  'ADEQUAÇÃO DA MORADIA': '2',
#  'MARCA DE IMPUTAÇÃO NA V0201:  ': '2',
#  'MARCA DE IMPUTAÇÃO NA V2011:': '2',
#  'MARCA DE IMPUTAÇÃO NA V0202: ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0203: ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0204: ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0205: ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0206: ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0207: ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0208: ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0209: ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0210: ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0211: ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0212: ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0213: ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0214:  ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0215: ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0216:  ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0217:  ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0218: ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0219:  ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0220:  ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0221:  ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0222:  ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0301:  ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0401:  ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0402:  ': '2',
#  'MARCA DE IMPUTAÇÃO NA V0701:  ': '2',
#  'Situação do setor ': '8'}

# %%
# file = "amostra_domicilios_2010_SC.txt"
# sc_line_dict = extract_line_values(file, dfs['amostra_domicilios_2010'])

# %%
df_domi
# Out:
#       VAR                                               NOME  POSIÇÃO INICIAL  \
# 0   V0001  UNIDADE DA FEDERAÇÃO:\n11- Rondônia\n12- Acre\...                1
# 1   V0002                                CÓDIGO DO MUNICÍPIO                3
# 2   V0011                                 ÁREA DE PONDERAÇÃO                8
# 3   V0300                                           CONTROLE               21
# 4   V0010                                      PESO AMOSTRAL               29
# ..    ...                                                ...              ...
# 71  M0301     MARCA DE IMPUTAÇÃO NA V0301:  \n1- Sim\n2- Não              168
# 72  M0401     MARCA DE IMPUTAÇÃO NA V0401:  \n1- Sim\n2- Não              169
# 73  M0402     MARCA DE IMPUTAÇÃO NA V0402:  \n1- Sim\n2- Não              170
# 74  M0701     MARCA DE IMPUTAÇÃO NA V0701:  \n1- Sim\n2- Não              171
# 75  V1005  Situação do setor \n1 - Área urbanizada\n2 - Á...              172
#
#     POSIÇÃO FINAL  INT   DEC TIPO
# 0               2    2   NaN    A
# 1               7    5   NaN    A
# 2              20   13   NaN    A
# 3              28    8   NaN    N
# 4              44    3  13.0    N
# ..            ...  ...   ...  ...
# 71            168    1   NaN    C
# 72            169    1   NaN    C
# 73            170    1   NaN    C
# 74            171    1   NaN    C
# 75            172    1   NaN    C
#
# [76 rows x 7 columns]
